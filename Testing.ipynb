# %%
import pandas as pd

# %%
df_1 = pd.read_csv('../noislamophobia-dataset-50k.csv')
df_2 = pd.read_csv('../noislamophobia-dataset-75k.csv')
df = pd.concat([df_1,df_2])
df.head()
# Out:
#                                   _id  contributors coordinates  \
# 0  ObjectId(59dbede4e6e465a2d67a1062)           NaN         NaN
# 1  ObjectId(59dbede4e6e465a2d67a106c)           NaN         NaN
# 2  ObjectId(59dbf266e6e465a2d67a4810)           NaN         NaN
# 3  ObjectId(59dbf266e6e465a2d67a4828)           NaN         NaN
# 4  ObjectId(59e8e630e6e465a2d6238c9c)           NaN         NaN
#
#                        created_at  \
# 0  Sun Oct 22 10:34:06 +0000 2017
# 1  Sun Oct 22 10:13:40 +0000 2017
# 2  Sun Oct 22 07:50:47 +0000 2017
# 3  Sun Oct 22 10:38:23 +0000 2017
# 4  Sun Oct 22 08:59:53 +0000 2017
#
#                                             entities extended_entities  \
# 0  {"hashtags":[{"text":"BanIslam","indices":[93,...               NaN
# 1  {"hashtags":[{"text":"muslim","indices":[16,23...               NaN
# 2  {"hashtags":[{"text":"Raqqa","indices":[37,43]...               NaN
# 3  {"hashtags":[],"symbols":[],"user_mentions":[{...               NaN
# ...

# %%
df.columns
# Out:
# Index(['_id', 'contributors', 'coordinates', 'created_at', 'entities',
#        'extended_entities', 'favorite_count', 'favorited', 'geo', 'id',
#        'id_str', 'in_reply_to_screen_name', 'in_reply_to_status_id',
#        'in_reply_to_status_id_str', 'in_reply_to_user_id',
#        'in_reply_to_user_id_str', 'is_quote_status', 'lang', 'metadata',
#        'place', 'possibly_sensitive', 'quoted_status', 'quoted_status_id',
#        'quoted_status_id_str', 'retweet_count', 'retweeted',
#        'retweeted_status', 'source', 'text', 'full_text', 'truncated', 'user',
#        'withheld_in_countries'],
#       dtype='object')

# %%
df = df.drop_duplicates()

# %%
df.head()['entities'][0]
# Out:
# '{"hashtags":[{"text":"BanIslam","indices":[93,102]},{"text":"DeportALLmuslims","indices":[109,126]}],"symbols":[],"user_mentions":[{"screen_name":"Private34349909","name":"Private User","id":7.976360710643794e+17,"id_str":"797636071064379392","indices":[3,19]},{"screen_name":"AmyMek","name":"Amy Mek","id":954124423,"id_str":"954124423","indices":[21,28]},{"screen_name":"Dab7One","name":"Dabney 1","id":2.850722943e+09,"id_str":"2850722943","indices":[29,37]},{"screen_name":"realDonaldTrump","name":"Donald J. Trump","id":25073877,"id_str":"25073877","indices":[41,57]},{"screen_name":"seanhannity","name":"Sean Hannity","id":41634520,"id_str":"41634520","indices":[58,70]},{"screen_name":"TuckerCarlson","name":"Tucker Carlson","id":22703645,"id_str":"22703645","indices":[71,85]}],"urls":[]}'

# %%
df.shape
# Out:
# (119019, 33)

# %%
df['created_at'][0]
# Out:
# 'Sun Oct 22 10:34:06 +0000 2017'

# %%
df['geo'].value_counts()
# Out:
# {"type":"Point","coordinates":[55.1639,-1.58639]}            1
# {"type":"Point","coordinates":[26.12046647,-80.1312959]}     1
# {"type":"Point","coordinates":[36.99099099,-85.94723833]}    1
# Name: geo, dtype: int64

# %%
df['text'][0]
# Out:
# 'RT @Private34349909: @AmyMek @Dab7One 1/ @realDonaldTrump @seanhannity @TuckerCarlson PLEASE #BanIslam &amp; #DeportALLmuslims They do NOT meet…'

# %%
df_na = df.dropna(axis=1, thresh=.75)
df_na.shape
# Out:
# (119019, 31)

# %%
df_na['extended_entities'].value_counts()
# Out:
# {"media":[{"id":9.392413551922299e+17,"id_str":"939241355192229888","indices":[65,88],"media_url":"http://pbs.twimg.com/media/DQjbCUaW4AArDbD.jpg","media_url_https":"https://pbs.twimg.com/media/DQjbCUaW4AArDbD.jpg","url":"https://t.co/dEr4552ajK","display_url":"pic.twitter.com/dEr4552ajK","expanded_url":"https://twitter.com/builditnow/status/939241536960782342/photo/1","type":"photo","sizes":{"small":{"w":680,"h":340,"resize":"fit"},"medium":{"w":750,"h":375,"resize":"fit"},"large":{"w":750,"h":375,"resize":"fit"},"thumb":{"w":150,"h":150,"resize":"crop"}},"source_status_id":9.392415369607823e+17,"source_status_id_str":"939241536960782342","source_user_id":9.211005303568384e+17,"source_user_id_str":"921100530356838400"}]}                                                                                                                                                                                                                                                                           
# ...

# %%
# can we break down the tweets into their sub-categories? 
# heatmap for days tweeted and word cloud (3)
# most popular hashtags overtime, see how things change over time (top 10 line graph over time)
# bar chart race (1)
# world map for tweets over time (heat map) (2)
df.sample(10)
# Out:
#                                       _id  contributors coordinates  \
# 31395  ObjectId(5c207934f0a32a0e32d8e004)           NaN         NaN
# 37774  ObjectId(5b722385a3d81d0e3790d025)           NaN         NaN
# 5154   ObjectId(5a0699e61928776402da83be)           NaN         NaN
# 42340  ObjectId(5ba3e82523dae20e0f9bb12f)           NaN         NaN
# 39298  ObjectId(5b8101c5a3addb0e0012eade)           NaN         NaN
# 48980  ObjectId(5f04b6ea856a76136b85d799)           NaN         NaN
# 32159  ObjectId(5c2b5995adaaeb0e221c7b8c)           NaN         NaN
# 19184  ObjectId(5b1340e522f69f0e2aa113ee)           NaN         NaN
# 42630  ObjectId(5d89f5d555989c0e9bd860b1)           NaN         NaN
# 47351  ObjectId(5e61707021f5fc15a467bbfe)           NaN         NaN
#
#                            created_at  \
# 31395  Mon Dec 24 05:58:42 +0000 2018
# 37774  Tue Aug 14 00:24:15 +0000 2018
# 5154   Sat Nov 11 06:27:04 +0000 2017
# 42340  Thu Sep 20 18:24:18 +0000 2018
# ...

# %%
df['possibly_sensitive'].value_counts()
# Out:
# False    34397
# True      6625
# Name: possibly_sensitive, dtype: int64

# %%
sensitive_df = df[df['possibly_sensitive'] == True]
n_sensitive_df = df[df['possibly_sensitive'] == False]

# %%
sensitive_df['lang'].values[-25]
# Out:
# 'en'

# %%
n_sensitive_df['text'].values[0]
# Out:
# 'RT @ensine: All #muslim rulers were savages bcoz #islamIsTheProblem, even profeet himself \n#TyrantTipu \nhttps://t.co/RqR4778Alr'

# %%
df['lang'].value_counts()
# Out:
# en     94348
# und    13477
# nl      5605
# de      1256
# hi      1096
# sv       971
# fr       534
# it       423
# el       255
# in       199
# es       186
# fa       104
# sl        78
# et        77
# da        67
# no        43
# ta        41
# tl        41
# ca        34
# pt        29
# ro        28
# ja        20
# tr        20
# cy        12
# pl        10
# cs         9
# ur         9
# lt         8
# ht         7
# zh         7
# hu         6
# fi         4
# ar         3
# is         2
# vi         2
# lv         2
# eu         2
# bn         1
# si         1
# ko         1
# ru         1
# Name: lang, dtype: int64

# %%
iso_639_choices = [('ab', 'Abkhaz'),
('aa', 'Afar'),
('af', 'Afrikaans'),
('ak', 'Akan'),
('sq', 'Albanian'),
('am', 'Amharic'),
('ar', 'Arabic'),
('an', 'Aragonese'),
('hy', 'Armenian'),
('as', 'Assamese'),
('av', 'Avaric'),
('ae', 'Avestan'),
('ay', 'Aymara'),
('az', 'Azerbaijani'),
('bm', 'Bambara'),
('ba', 'Bashkir'),
('eu', 'Basque'),
('be', 'Belarusian'),
('bn', 'Bengali'),
('bh', 'Bihari'),
('bi', 'Bislama'),
('bs', 'Bosnian'),
('br', 'Breton'),
('bg', 'Bulgarian'),
('my', 'Burmese'),
('ca', 'Catalan; Valencian'),
('ch', 'Chamorro'),
('ce', 'Chechen'),
('ny', 'Chichewa; Chewa; Nyanja'),
('zh', 'Chinese'),
('cv', 'Chuvash'),
('kw', 'Cornish'),
('co', 'Corsican'),
('cr', 'Cree'),
('hr', 'Croatian'),
('cs', 'Czech'),
('da', 'Danish'),
('dv', 'Divehi; Maldivian;'),
('nl', 'Dutch'),
('dz', 'Dzongkha'),
('en', 'English'),
('eo', 'Esperanto'),
('et', 'Estonian'),
('ee', 'Ewe'),
('fo', 'Faroese'),
('fj', 'Fijian'),
('fi', 'Finnish'),
('fr', 'French'),
('ff', 'Fula'),
('gl', 'Galician'),
('ka', 'Georgian'),
('de', 'German'),
('el', 'Greek, Modern'),
('gn', 'Guaraní'),
('gu', 'Gujarati'),
('ht', 'Haitian'),
('ha', 'Hausa'),
('he', 'Hebrew (modern)'),
('hz', 'Herero'),
('hi', 'Hindi'),
('ho', 'Hiri Motu'),
('hu', 'Hungarian'),
('ia', 'Interlingua'),
('id', 'Indonesian'),
('ie', 'Interlingue'),
('ga', 'Irish'),
('ig', 'Igbo'),
('ik', 'Inupiaq'),
('io', 'Ido'),
('is', 'Icelandic'),
('it', 'Italian'),
('iu', 'Inuktitut'),
('ja', 'Japanese'),
('jv', 'Javanese'),
('kl', 'Kalaallisut'),
('kn', 'Kannada'),
('kr', 'Kanuri'),
('ks', 'Kashmiri'),
('kk', 'Kazakh'),
('km', 'Khmer'),
('ki', 'Kikuyu, Gikuyu'),
('rw', 'Kinyarwanda'),
('ky', 'Kirghiz, Kyrgyz'),
('kv', 'Komi'),
('kg', 'Kongo'),
('ko', 'Korean'),
('ku', 'Kurdish'),
('kj', 'Kwanyama, Kuanyama'),
('la', 'Latin'),
('lb', 'Luxembourgish'),
('lg', 'Luganda'),
('li', 'Limburgish'),
('ln', 'Lingala'),
('lo', 'Lao'),
('lt', 'Lithuanian'),
('lu', 'Luba-Katanga'),
('lv', 'Latvian'),
('gv', 'Manx'),
('mk', 'Macedonian'),
('mg', 'Malagasy'),
('ms', 'Malay'),
('ml', 'Malayalam'),
('mt', 'Maltese'),
('mi', 'Māori'),
('mr', 'Marathi (Marāṭhī)'),
('mh', 'Marshallese'),
('mn', 'Mongolian'),
('na', 'Nauru'),
('nv', 'Navajo, Navaho'),
('nb', 'Norwegian Bokmål'),
('nd', 'North Ndebele'),
('ne', 'Nepali'),
('ng', 'Ndonga'),
('nn', 'Norwegian Nynorsk'),
('no', 'Norwegian'),
('ii', 'Nuosu'),
('nr', 'South Ndebele'),
('oc', 'Occitan'),
('oj', 'Ojibwe, Ojibwa'),
('cu', 'Old Church Slavonic'),
('om', 'Oromo'),
('or', 'Oriya'),
('os', 'Ossetian, Ossetic'),
('pa', 'Panjabi, Punjabi'),
('pi', 'Pāli'),
('fa', 'Persian'),
('pl', 'Polish'),
('ps', 'Pashto, Pushto'),
('pt', 'Portuguese'),
('qu', 'Quechua'),
('rm', 'Romansh'),
('rn', 'Kirundi'),
('ro', 'Romanian, Moldavan'),
('ru', 'Russian'),
('sa', 'Sanskrit (Saṁskṛta)'),
('sc', 'Sardinian'),
('sd', 'Sindhi'),
('se', 'Northern Sami'),
('sm', 'Samoan'),
('sg', 'Sango'),
('sr', 'Serbian'),
('gd', 'Scottish Gaelic'),
('sn', 'Shona'),
('si', 'Sinhala, Sinhalese'),
('sk', 'Slovak'),
('sl', 'Slovene'),
('so', 'Somali'),
('st', 'Southern Sotho'),
('es', 'Spanish; Castilian'),
('su', 'Sundanese'),
('sw', 'Swahili'),
('ss', 'Swati'),
('sv', 'Swedish'),
('ta', 'Tamil'),
('te', 'Telugu'),
('tg', 'Tajik'),
('th', 'Thai'),
('ti', 'Tigrinya'),
('bo', 'Tibetan'),
('tk', 'Turkmen'),
('tl', 'Tagalog'),
('tn', 'Tswana'),
('to', 'Tonga'),
('tr', 'Turkish'),
('ts', 'Tsonga'),
('tt', 'Tatar'),
('tw', 'Twi'),
('ty', 'Tahitian'),
('ug', 'Uighur, Uyghur'),
('uk', 'Ukrainian'),
('ur', 'Urdu'),
('uz', 'Uzbek'),
('ve', 'Venda'),
('vi', 'Vietnamese'),
('vo', 'Volapük'),
('wa', 'Walloon'),
('cy', 'Welsh'),
('wo', 'Wolof'),
('fy', 'Western Frisian'),
('xh', 'Xhosa'),
('yi', 'Yiddish'),
('yo', 'Yoruba'),
('za', 'Zhuang, Chuang'),
('zu', 'Zulu'),]

# %%
import pycountry
import numpy as np

countries = np.unique(df['lang'].values)
codes = {}

for c in countries:
    try:
        codes[c] = dict(iso_639_choices)[c]
    except:
        codes[c] = 'None'

# %%
codes
# Out:
# {'ar': 'Arabic',
#  'bn': 'Bengali',
#  'ca': 'Catalan; Valencian',
#  'cs': 'Czech',
#  'cy': 'Welsh',
#  'da': 'Danish',
#  'de': 'German',
#  'el': 'Greek, Modern',
#  'en': 'English',
#  'es': 'Spanish; Castilian',
#  'et': 'Estonian',
#  'eu': 'Basque',
#  'fa': 'Persian',
#  'fi': 'Finnish',
#  'fr': 'French',
#  'hi': 'Hindi',
#  'ht': 'Haitian',
#  'hu': 'Hungarian',
#  'in': 'None',
#  'is': 'Icelandic',
#  'it': 'Italian',
#  'ja': 'Japanese',
#  'ko': 'Korean',
#  'lt': 'Lithuanian',
#  'lv': 'Latvian',
#  'nl': 'Dutch',
#  'no': 'Norwegian',
#  'pl': 'Polish',
#  'pt': 'Portuguese',
#  'ro': 'Romanian, Moldavan',
#  'ru': 'Russian',
#  'si': 'Sinhala, Sinhalese',
#  'sl': 'Slovene',
#  'sv': 'Swedish',
#  'ta': 'Tamil',
#  'tl': 'Tagalog',
#  'tr': 'Turkish',
#  'und': 'None',
#  'ur': 'Urdu',
#  'vi': 'Vietnamese',
#  'zh': 'Chinese'}

# %%
df['entities'][0]
# Out:
# '{"hashtags":[{"text":"BanIslam","indices":[93,102]},{"text":"DeportALLmuslims","indices":[109,126]}],"symbols":[],"user_mentions":[{"screen_name":"Private34349909","name":"Private User","id":7.976360710643794e+17,"id_str":"797636071064379392","indices":[3,19]},{"screen_name":"AmyMek","name":"Amy Mek","id":954124423,"id_str":"954124423","indices":[21,28]},{"screen_name":"Dab7One","name":"Dabney 1","id":2.850722943e+09,"id_str":"2850722943","indices":[29,37]},{"screen_name":"realDonaldTrump","name":"Donald J. Trump","id":25073877,"id_str":"25073877","indices":[41,57]},{"screen_name":"seanhannity","name":"Sean Hannity","id":41634520,"id_str":"41634520","indices":[58,70]},{"screen_name":"TuckerCarlson","name":"Tucker Carlson","id":22703645,"id_str":"22703645","indices":[71,85]}],"urls":[]}'
