# %%
import pandas as pd
import json
from collections import defaultdict, Counter
import datetime
from tqdm import tqdm
import bar_chart_race as bcr
import matplotlib.pyplot as plt

# %%
df_50k = pd.read_csv('../noislamophobia-dataset-50k.csv')
df_75k = pd.read_csv('../noislamophobia-dataset-75k.csv')
df = pd.concat([df_50k,df_75k])
df.head()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3018: DtypeWarning: Columns (2,8,32) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                                   _id  contributors coordinates  \
# 0  ObjectId(59dbede4e6e465a2d67a1062)           NaN         NaN
# 1  ObjectId(59dbede4e6e465a2d67a106c)           NaN         NaN
# 2  ObjectId(59dbf266e6e465a2d67a4810)           NaN         NaN
# 3  ObjectId(59dbf266e6e465a2d67a4828)           NaN         NaN
# 4  ObjectId(59e8e630e6e465a2d6238c9c)           NaN         NaN
#
#                        created_at  \
# 0  Sun Oct 22 10:34:06 +0000 2017
# 1  Sun Oct 22 10:13:40 +0000 2017
# 2  Sun Oct 22 07:50:47 +0000 2017
# 3  Sun Oct 22 10:38:23 +0000 2017
# 4  Sun Oct 22 08:59:53 +0000 2017
#
#                                             entities extended_entities  \
# 0  {"hashtags":[{"text":"BanIslam","indices":[93,...               NaN
# 1  {"hashtags":[{"text":"muslim","indices":[16,23...               NaN
# 2  {"hashtags":[{"text":"Raqqa","indices":[37,43]...               NaN
# 3  {"hashtags":[],"symbols":[],"user_mentions":[{...               NaN
# 4  {"hashtags":[{"text":"RT","indices":[51,54]},{...               NaN
#
#    favorite_count  favorited  geo            id  ...  quoted_status_id_str  \
# 0               0      False  NaN  9.220484e+17  ...                   NaN
# 1               0      False  NaN  9.220433e+17  ...                   NaN
# 2               0      False  NaN  9.220073e+17  ...                   NaN
# 3               0      False  NaN  9.220495e+17  ...                   NaN
# 4               0      False  NaN  9.220247e+17  ...                   NaN
#
#   retweet_count  retweeted                                   retweeted_status  \
# 0             4      False  {"created_at":"Fri Oct 20 09:33:45 +0000 2017"...
# 1            10      False  {"created_at":"Sat Oct 21 18:37:07 +0000 2017"...
# 2           172      False  {"created_at":"Fri Oct 20 23:15:45 +0000 2017"...
# 3             1      False                                                NaN
# 4            25      False  {"created_at":"Sun Oct 22 01:40:55 +0000 2017"...
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/android" ...
# 2  <a href="http://twitter.com/download/android" ...
# 3  <a href="http://twitter.com" rel="nofollow">Tw...
# 4  <a href="http://twitter.com/download/android" ...
#
#                                                 text  full_text truncated  \
# 0  RT @Private34349909: @AmyMek @Dab7One 1/ @real...        NaN     False
# 1  RT @ensine: All #muslim rulers were savages bc...        NaN     False
# 2  RT @SLandinSoCal: Liberated Women of #Raqqa‼️R...        NaN     False
# 3  @Stormtroepen @cdavandaag @sybrandbuma @gertja...        NaN      True
# 4  RT @PoliticalIslam: Sharia at odds with Articl...        NaN     False
#
#                                                 user withheld_in_countries
# 0  {"id":8.009259051368776e+17,"id_str":"80092590...                   NaN
# 1  {"id":375089876,"id_str":"375089876","name":"द...                   NaN
# 2  {"id":7.092975641898926e+17,"id_str":"70929756...                   NaN
# 3  {"id":1340408646,"id_str":"1340408646","name":...                   NaN
# 4  {"id":150595824,"id_str":"150595824","name":"🇮...                ["DE"]
#
# [5 rows x 33 columns]

# %%
df = df.drop_duplicates()
df_na = df.dropna(axis=1, thresh=.75)

# %%
table = defaultdict(int)

for entity in df['entities']:
    test = json.loads(entity)
    for x in test['hashtags']:
            table[x['text'].lower()] += 1
print(table)
# Out:
# defaultdict(<class 'int'>, {'banislam': 28780, 'deportallmuslims': 23, 'muslim': 5480, 'islamistheproblem': 8704, 'tyranttipu': 2, 'raqqa': 23, 'burqa': 26, 'islam': 6305, 'bansharia': 13500, 'rt': 1136, 'stopislam': 2660, 'tcot': 692, 'billwarnerphd': 838, 'makedclisten': 724, 'iran': 440, 'stopislamization': 368, 'hope4women': 193, 'jihad': 1606, 'uk': 4398, 'dianneabbott': 1, 'ejected': 1, 'assaulted': 1, 'iraqi': 2, 'british': 129, 'shariacantbelaw': 1, 'shariaviolatesuslaw': 2, 'cruelandunusual': 2, 'islamoutofusnow': 1, 'nousmosques': 8, 'merkles': 15, 'maga': 4156, 'wtf': 13, 'omg': 6, 'banthequranasahatebook': 70, 'bansharialaw': 4006, 'bandumbasshollywoodliars': 3, 'islamisacult': 107, 'cspi': 523, 'isupportpresidenttrump': 58, 'trump2020': 589, '1a': 155, '2a': 320, 'americafirst': 1471, 'nogozones': 55, 'buildthewall': 1666, 'everify': 4, 'deportthemall': 465, 'nomorerefugees': 27, 'pedophiles': 21, 'pedophilia': 33, 'politicalislam': 200, 'muhammad': 198, 'feminism': 11, 'thisisislam': 245, 'satansspawn': 37, 'islamsupremacyhatecult': 156, 'sundaymorning': 203, 'queenelizabeth': 2, 'americans': 113, 'creepingsharia': 305, 'backtheblue': 36, 'europe': 530, 'whitegenocide': 72, 'religionbeliefs': 1298, 'patriotic': 1294, 'tomtrento': 15, 'siliconvalley': 67, 'rair': 104, 'banislamicpropgators': 1, 'banpolygamy': 26, 'michigan': 182, 'toredown': 15, 'civilwar': 23, 'islamisadeathcult': 44, 'islambadforwomen': 49, 'islambadforgirls': 42, 'dts': 23, 'deportillegals': 60, 'stopimmigration': 49, 'nosharia': 1051, 'stopm103': 200, 'liberalsmustgo': 150, 'trudeaumustgo': 382, 'canada': 529, 'cdnpoli': 301, 'ontpoli': 83, 'polpc': 1, 'polmtl': 144, 'ableg': 154, 'exmuslims': 34, 'exmuslim': 135, 'exmuslimbecause': 161, 'atheism': 8, 'atheist': 9, 'atheists': 10, 'religionofpeace': 4469, 'isis': 982, 'stopisis': 10, 'banmuslimimmigration': 26, 'muslimterrorism': 33, 'predatorwood': 7, 'banhollywood': 7, 'travelban': 577, 'realwaronwomen': 215, 'bantheburka': 241, 'banthequran': 320, 'america': 1267, 'sharialaw': 908, 'terrorist': 283, 'nomoreislam': 59, 'stopimportingislam': 499, 'stoptheislaizationoftheworld': 4, 'islamexposed': 6135, 'boycottpepsi': 1, 'standupforamerica': 2, 'islamisevil': 547, 'endislam': 716, 'stopbeatingwomen': 9, 'stopfgm': 149, 'stopsharia': 25, 'saudibarbaria': 2, 'stoptheislamizationofamerica': 8, 'stopimportingterrorists': 3, 'god': 202, 'ourfather': 95, 'allah': 621, 'slave': 125, 'master': 96, 'iamachildofgod': 141, 'teamjesus': 101, 'jihadistlinda': 10, 'jihadistnotwelcome': 50, 'arrestlindasarsour': 20, 'wakeupamericans': 30, 'closeallmosques': 98, 'stopbuildingmosques': 273, 'neversubmittoislam': 203, 'educateyourselfonislam': 689, 'stoptheislamizationoftheworld': 31, 'radicalislamic': 16, 'terrorism': 306, 'stopthehate': 10, 'norefugees': 255, 'nohijabday': 24, 'islamisdangerous': 359, 'wakeupworld': 196, 'banfgm': 259, 'bancairnational': 119, 'banthemuslimbrotherhood': 103, 'gent': 27, 'verzet': 216, 'stoptheislamicinvasion': 81, 'honorkillings': 18, 'invasion': 178, 'iambritish': 4, 'vetting': 2, 'generationidentity': 3, 'fightback': 71, 'protectourpets': 2, 'staystrong': 169, 'inbreedingandbrainwashing': 101, 'stopmakingexcusesforislam': 142, 'deportnow': 20, 'followourlaws': 2, 'mccarranwaltersact': 19, 'pl414': 2, 'returntosender': 1, 'illegalgohome': 1, 'noamnesty': 86, 'nodaca': 121, 'gtfo': 27, 'fgm': 431, 'protectlittlegirls': 40, 'cair': 814, 'muslimbrotherhood': 507, 'wakeupamerica': 1234, 'polqc': 160, 'truexit2019': 31, 'quebec': 32, 'koran': 143, 'noislam': 526, 'cultofevil': 19, 'realwarinwomen': 5, 'endfgm': 85, 'childnotbride': 5, 'coptic': 3, 'egypt': 66, 'muslimban': 639, 'rapefuges': 2, 'death2america': 13, 'nosharialaw': 186, 'sanctuarycities': 19, 'karma': 3, 'constitution': 168, 'theconstitution': 9, 'tuesdaythoughts': 40, 'sharia': 827, 'smh': 47, 'travelingshariaban': 1, 'islamisanevildeathcult': 1, 'neversharia': 25, 'moslemsarentvictims': 12, 'stopmakingexcusesformo ...

# %%
df_datetime = pd.to_datetime(df['created_at']).dt.date
df_datetime.head()
# Out:
# 0    2017-10-22
# 1    2017-10-22
# 2    2017-10-22
# 3    2017-10-22
# 4    2017-10-22
# Name: created_at, dtype: object

# %%
df_datetime.hist(figsize=(10,10), bins=100)
plt.show()

# %%
table = dict(sorted(table.items(), key=lambda item: item[1], reverse=True))
table
# Out:
# {'banislam': 28780,
#  'bansharia': 13500,
#  'islamistheproblem': 8704,
#  'islam': 6305,
#  'islamexposed': 6135,
#  'muslim': 5480,
#  'religionofpeace': 4469,
#  'uk': 4398,
#  'maga': 4156,
#  'bansharialaw': 4006,
#  'stopislam': 2660,
#  'britain': 2512,
#  'muslims': 2297,
#  'buildthewall': 1666,
#  'jihad': 1606,
#  'americafirst': 1471,
#  'religionbeliefs': 1298,
#  'patriotic': 1294,
#  'america': 1267,
#  'wakeupamerica': 1234,
#  'islamic': 1173,
#  'rt': 1136,
#  'rapejihad': 1096,
#  'nosharia': 1051,
#  'isis': 982,
#  'stopcarnage': 964,
#  'pvv': 937,
#  'sharialaw': 908,
#  'billwarnerphd': 838,
#  'sharia': 827,
#  'cair': 814,
#  'islamicstate': 801,
#  'kag': 760,
#  'breaking': 751,
#  'makedclisten': 724,
#  'endislam': 716,
#  'christian': 716,
#  'tcot': 692,
#  'educateyourselfonislam': 689,
#  'terror': 678,
#  'qanon': 651,
#  'freetommy': 641,
#  'muslimban': 639,
#  'migrant': 631,
#  'allah': 621,
#  'usa': 619,
#  'trump2020': 589,
#  'freetommyrobinson': 586,
#  'us': 580,
#  'travelban': 577,
#  'rape': 562,
#  'france': 558,
#  'immigrationreform': 556,
#  'bannogozones': 554,
#  'lilbulli': 553,
#  'germany': 552,
#  'islamisevil': 547,
#  'draintheswamp': 536,
#  'europe': 530,
#  'canada': 529,
#  'noislam': 526,
#  'cspi': 523,
#  'muslimbrotherhood': 507,
#  'stopimportingislam': 499,
#  'pakistan': 498,
#  'islamophobia': 477,
#  'banmuslimbrotherhoods': 474,
#  'trump': 472,
#  'deportthemall': 465,
#  'allahuakbar': 458,
#  'veterans': 451,
#  'lindasarsour': 450,
#  'iran': 440,
#  'trumptrain': 440,
#  'bancair': 437,
#  'fgm': 431,
#  'banmuslims': 421,
#  'ramadan': 411,
#  'closernation': 398,
#  'walkaway': 391,
#  'tocatchathief': 391,
#  'minnesota': 390,
#  'shariakills': 389,
#  'wwg1wga': 386,
#  'quran': 385,
#  'potus': 383,
#  'trudeaumustgo': 382,
#  'hamas': 377,
#  'stopislamization': 368,
#  'murder': 368,
#  'islamisdangerous': 359,
#  'bantheburqa': 359,
#  'ovc16': 359,
#  'sweden': 346,
#  'banshariahlaw': 342,
#  'christians': 341,
#  'london': 339,
#  'nothinggoodcomesfromislam': 335,
#  'israel': 330,
#  'police': 329,
#  'australia': 325,
#  'ilhanomar': 323,
#  'nyc': 321,
#  '2a': 320,
#  'banthequran': 320,
#  'civilizationjihad': 318,
#  'svpol': 314,
#  'extremevetting': 313,
#  'closermoments': 310,
#  'terrorism': 306,
#  'creepingsharia': 305,
#  'cantcoexist': 305,
#  'cdnpoli': 301,
#  'migrants': 294,
#  'tommyrobinson': 286,
#  'immigration': 284,
#  'terrorist': 283,
#  'remove': 280,
#  'stopbuildingmosques': 273,
#  'impeachilhanomar': 267,
#  'mallofamerica': 264,
#  'bewaretaqiyya': 262,
#  'wethepeople': 260,
#  'banfgm': 259,
#  'norefugees': 255,
#  'imam': 255,
#  'jihadis': 255,
#  'democrats': 251,
#  'paris': 251,
#  'multiculturalism': 248,
#  'manhattan': 246,
#  'thisisislam': 245,
#  'obama': 245,
#  'noopenborders': 244,
#  'gelehesjes': 242,
#  'bantheburka': 241,
#  'banhalal': 238,
#  'diversity': 236,
#  'evil': 233,
#  'nexit': 233,
#  'stemzeweg': 233,
#  'refugee': 231,
#  'islamicterrorism': 229,
#  'banmosques': 229,
#  'eu': 227,
#  'mosque': 224,
#  'child': 224,
#  'children': 223,
#  'texas': 223,
#  'nigeria': 217,
#  'verzet': 216,
#  'realwaronwomen': 215,
#  'freespeech': 213,
#  'west': 213,
#  'terrorists': 211,
#  'rashidatlaib': 211,
#  'death': 210,
#  'removeomar': 206,
#  'attack': 205,
#  'sundaymorning': 203,
#  'neversubmittoislam': 203,
#  'trumpsarmy': 203,
#  'notmypact': 203,
#  'god': 202,
#  'pegida': 202,
#  'impeachrashidatlaib': 201,
#  'politicalislam': 200,
#  'stopm103': 200,
#  'stopimportingislamicterrorism': 200,
#  'muhammad': 198,
#  'brd': 198,
#  'endchildtrafficking': 197,
#  'wakeupworld': 196,
#  'deportmuslims': 196,
#  'newyork': 195,
#  'hope4women': 193,
#  'jews': 192,
#  'russia': 192,
#  'jesuschrist': 190,
#  'wakeup': 189,
#  'banquran': 189,
#  'enddaca': 187,
#  'nosharialaw': 186,
#  'hijab': 185,
#  'sex': 183,
#  'michigan': 182,
#  'patriots': 182,
#  'thursdaythoughts': 181,
#  'women': 181,
#  'invasion': 178,
#  'california': 178,
#  'liberalismisamentaldisorder': 177,
#  'notmyun': 177,
#  'fuckislam': 176,
#  'brexit': 175,
#  'florida': 173,
#  'sunnah': 173,
#  'banmuslimbrotherhood': 171,
#  'jihadi': 171,
#  'afghanistan': 170,
#  'staystrong': 169,
#  'constitution': 168,
#  'hate': 168,
#  'american': 168,
#  'morocco': 167,
#  'nra': 165,
#  'grenzendicht': 165,
#  'news': 165,
#  'makeamericasafeagain': 163,
#  'stopterrorism': 163,
#  'neverforget': 162,
#  'exmuslimbecause': 161,
#  'islamicdanger': 161,
#  'polqc': 160,
#  'takeheed': 160,
#  'deislamiseren': 158,
#  'islamsupremacyhatecult': 156,
#  'truth': 156,
#  'controltheborders': 156,
#  'borderslanguageculture': 156,
#  '1a': 155,
#  'convert': 155,
#  'ableg': 154,
#  'politics': 154,
#  'attacks': 152,
#  'muslima': 151,
#  'liberalsmustgo': 150,
#  'trudeau': 150,
#  'migration': 150,
#  'freedomoffspeech': 150,
#  'notmyeu': 150,
#  'stopfgm': 149,
#  'bacon': 149,
#  'boycott': 149,
#  'refugees': 147,
#  'radical': 147,
#  'facebook': 147,
#  'newjersey': 147,
#  'godblessamerica': 146,
#  'ohio': 146,
#  'mosques': 145,
#  'polmtl': 144,
#  'squad': 144,
#  'koran': 143,
#  'merkel': 143,
#  'freedomofspeech': 143,
#  'violent': 143,
#  'nomassmigration': 143,
#  'stopmakingexcusesforislam': 142,
#  'palestinian': 142,
#  'kill': 142,
#  'iamachildofgod': 141,
#  'stopthehateislam': 141,
#  'turkey': 140,
#  'ccot': 139,
#  'daca': 139,
#  'toronto': 138,
#  'noillegals': 138,
#  'southcarolina': 138,
#  'truemaga': 137,
#  'history': 136,
#  'voterid': 136,
#  'exmuslim': 135,
#  'readexplanatorymemorandum': 135,
#  'congress': 134,
#  'muslimsarentvictims': 134,
#  'banthehijab': 134,
#  'stopimportingislamicterror': 134,
#  'poland': 133,
#  'kids': 133,
#  'pedogate': 131,
#  'enoughisenough': 130,
#  'istandwithisrael': 130,
#  'british': 129,
#  'christmas': 129,
#  'senate': 129,
#  'neverforget911': 129,
#  'eradicatehamas': 129,
#  'erdogan': 128,
#  'dresden': 128,
#  'hypocrite': 128,
#  'kentucky': 128,
#  'childmarriage': 127,
#  'jewish': 127,
#  'twitter': 127,
#  'sniper': 127,
#  'mcgrath': 127,
#  'aufdiestraße': 126,
#  'europa': 126,
#  'slave': 125,
#  'england': 125,
#  'lockherup': 125,
#  'stempvv': 124,
#  'manhattanattack': 122,
#  'drivethemout': 122,
#  'saudiarabia': 122,
#  'soldiers': 122,
#  'nodaca': 121,
#  'liberals': 121,
#  'netherlands': 120,
#  'bancairnational': 119,
#  'oh': 119,
#  'maryland': 116,
#  'blasphemy': 116,
#  'allahakbar': 115,
#  'hinduism': 115,
#  'americans': 113,
#  'chemnitz': 113,
#  'jihadgtfo': 113,
#  'corrupt': 113,
#  'retweet': 112,
#  'canadians': 112,
#  'ontario': 112,
#  'sindh': 112,
#  'जय_श्रीराम': 112,
#  'crusades': 111,
#  'racist': 111,
#  'austria': 111,
#  'knife': 111,
#  'combattant': 111,
#  'jetzterstrecht': 110,
#  'alqaeda': 110,
#  'auspol': 109,
#  'ban': 109,
#  'muslimbanforever': 109,
#  'happynewyear': 109,
#  'genocide': 108,
#  'islamisacult': 107,
#  'middleeast': 107,
#  'redawaken': 107,
#  'infidels': 106,
#  'boston': 106,
#  'hijrah': 106,
#  'theresistance': 106,
#  'lauraingraham': 105,
#  'extreemvettingnow': 105,
#  'obamagate': 105,
#  'amsterdam': 105,
#  'bokoharam': 105,
#  'kominverzet': 105,
#  'german': 105,
#  'georgia': 105,
#  'rair': 104,
#  'minnesotastan': 104,
#  'sachsen': 104,
#  'leipzig': 104,
#  'honor': 104,
#  'banthemuslimbrotherhood': 103,
#  'sundaythoughts': 103,
#  'fakerefugees': 102,
#  'teamjesus': 101,
#  'inbreedingandbrainwashing': 101,
#  'wednesdaywisdom': 101,
#  'knowthefactsaboutislam': 101,
#  'democratvoterfraud': 100,
#  'voteridnow': 100,
#  'caliphate': 99,
#  'fakenews': 99,
#  'commoncore': 99,
#  'halal': 99,
#  'stophijrah': 99,
#  'doublestandards': 99,
#  'massacre': 99,
#  'closeallmosques': 98,
#  'msm': 98,
#  'syria': 98,
#  'closemosques': 98,
#  'destruction': 98,
#  'bradford': 98,
#  'resignomar': 98,
#  'nycterroristattack': 97,
#  'banburkas': 97,
#  'votethemout': 97,
#  'master': 96,
#  'speakerscorner': 96,
#  'beheaded': 96,
#  'closerlivelaunch': 96,
#  'ourfather': 95,
#  'sayfullosaipov': 95,
#  'freedom': 95,
#  'globalists': 95,
#  'victim': 95,
#  'converts': 95,
#  'patriotsawakened': 95,
#  'polska': 95,
#  'onpoli': 94,
#  'propaganda': 94,
#  'theymeanusharm': 94,
#  'illinois': 93,
#  'scotland': 93,
#  'warsaw': 93,
#  'religionofpeacemyass': 92,
#  'mattel': 92,
#  'fulani': 92,
#  'warszawa': 92,
#  'nystrong': 91,
#  'banislaminamerica': 91,
#  'islamophobe': 91,
#  'moslems': 91,
#  'migpol': 91,
#  'islamist': 91,
#  'africa': 91,
#  'video': 90,
#  'alive': 90,
#  'bombathon': 90,
#  'italy': 88,
#  'buildthatwall': 88,
#  'endchainmigration': 88,
#  'finland': 88,
#  'counterterror': 88,
#  'abolishcair': 88,
#  'rejectrashida': 88,
#  'nothingtodowithislam': 87,
#  'islamisterrorism': 87,
#  'iranprotests': 87,
#  'holland': 87,
#  'noislamization': 87,
#  'tunisia': 87,
#  'danger': 87,
#  'noamnesty': 86,
#  'peace': 86,
#  'crusade': 86,
#  'barbaric': 86,
#  'war': 86,
#  'votered': 86,
#  'tunis': 86,
#  'explosives': 86,
#  'andersoncounty': 86,
#  'endfgm': 85,
#  'islamisering': 85,
#  'military': 85,
#  'hungary': 85,
#  'muslimterror': 84,
#  'hillaryforprison': 84,
#  'm103': 84,
#  'army': 84,
#  'rapes': 84,
#  'bomb': 84,
#  'therainmakers': 84,
#  'horror': 84,
#  'ontpoli': 83,
#  'lgbt': 83,
#  'thestorm': 83,
#  'fakenewsmedia': 83,
#  'россия': 83,
#  'belgium': 82,
#  'gays': 82,
#  'bruder': 82,
#  'schwester': 82,
#  'familie': 82,
#  'duitsland': 82,
#  'stoptheislamicinvasion': 81,
#  'erzgebirge': 81,
#  'samoli': 81,
#  'brigittegabriel': 80,
#  'slaughter': 80,
#  'ditchtheun': 80,
#  'sussex': 80,
#  'faithschools': 80,
#  'weinstein': 79,
#  'islamization': 79,
#  'jerusalem': 79,
#  'media': 79,
#  'jihadijustin': 79,
#  'killthecultofevil': 78,
#  'democrat': 78,
#  'podesta': 78,
#  'spacey': 78,
#  'investigatehollywood': 78,
#  'prolife': 78,
#  'treason': 78,
#  'boycottmacys': 78,
#  'deport': 77,
#  'antifa': 77,
#  'norway': 77,
#  'telford': 77,
#  'jesus': 77,
#  'kag2020': 77,
#  'numnutsnadler': 77,
#  'sheffield': 77,
#  'voteredtosaveamerica2020': 77,
#  'isil': 76,
#  'willsmith': 76,
#  'darkness': 76,
#  'timetopaythebarrtab': 76,
#  'closerfamily': 76,
#  'dkpol': 75,
#  'noshariainusa': 75,
#  'thegreatawakening': 75,
#  'banhijab': 74,
#  'taqiyya': 74,
#  'islamists': 74,
#  'geertwilders': 74,
#  'mondaymotivation': 74,
#  'resigntlaib': 74,
#  'stoke': 74,
#  'stokeontrent': 74,
#  'closethemosques': 73,
#  'deutschland': 73,
#  'leftists': 73,
#  'greatawakening': 73,
#  'india': 73,
#  'gr2018': 73,
#  'gr18': 73,
#  'manhunt': 73,
#  'whitegenocide': 72,
#  'jesusislord': 72,
#  'evidence': 72,
#  'merrychristmas': 72,
#  'bible': 72,
#  'jew': 72,
#  'firingsquad': 72,
#  'jordan': 72,
#  'fightback': 71,
#  'mohammed': 71,
#  'globalist': 71,
#  'firetrudeau': 71,
#  'onenationundergod': 71,
#  'saveeurope': 71,
#  'afd': 71,
#  'muslimwomensday': 71,
#  'banshariatcourt': 71,
#  'minneapolis': 71,
#  'chechnya': 71,
#  'endthefed': 71,
#  'banthequranasahatebook': 70,
#  'trudeaumustgo2018': 70,
#  'metoo': 70,
#  'school': 70,
#  'french': 70,
#  'vienna': 70,
#  'freetommyrobinsonnow': 70,
#  'amazon': 70,
#  'worthing': 70,
#  'gaza': 69,
#  'radicalislamisislam': 69,
#  'इस्लाम': 69,
#  'wilders': 69,
#  'deathpenalty': 69,
#  'ikea': 69,
#  'mekka': 69,
#  'wetzlar': 69,
#  'hessen': 69,
#  'rughead': 68,
#  'sexual': 68,
#  'bombing': 68,
#  'assault': 68,
#  'court': 68,
#  'sacrificial': 68,
#  'ny': 68,
#  'ps2019': 68,
#  'siliconvalley': 67,
#  'grooming': 67,
#  'resign': 67,
#  'exmuslimlivesmatter': 67,
#  'egypt': 66,
#  'culturalenrichment': 66,
#  'barcelona': 66,
#  'theawakening': 66,
#  'conference': 66,
#  'gang': 66,
#  'jesussaves': 66,
#  'saynotoislam': 65,
#  'orlando': 65,
#  'rotherham': 65,
#  'palestine': 65,
#  'thestormishere': 64,
#  'proudinfidel': 64,
#  'rapist': 64,
#  'trumpworld': 64,
#  'spain': 64,
#  'беслан': 64,
#  'jerusalemembassy': 63,
#  'islamkills': 63,
#  'grotesque': 63,
#  'islamicrapegangs': 63,
#  'flag': 63,
#  'twgrp': 63,
#  'lyon': 63,
#  'savecordovatn': 63,
#  'beslan': 63,
#  'alaska': 63,
#  'usconstitution': 62,
#  'resignnow': 62,
#  'resist': 62,
#  'portauthority': 62,
#  'killing': 62,
#  'victims': 62,
#  'guilty': 62,
#  'forced': 62,
#  'blood': 62,
#  'pennsylvania': 62,
#  'deathcult': 61,
#  'religion': 61,
#  'feminists': 61,
#  'islamiscancer': 61,
#  'suddenjihadsyndrome': 61,
#  'sossekaos': 61,
#  'thankyou': 61,
#  'releasethememo': 61,
#  'democratsaredangerous': 61,
#  'incest': 61,
#  'dirtydems': 61,
#  'onlyjesus': 61,
#  'saveusjesus': 61,
#  'goback': 61,
#  'deportillegals': 60,
#  'guncontrol': 60,
#  'islamisacancer': 60,
#  'muslimkaos': 60,
#  'training': 60,
#  'armed': 60,
#  'nomoreislam': 59,
#  'speakup': 59,
#  'akayedullah': 59,
#  'stabbing': 59,
#  'rotterdam': 59,
#  'incompatibility': 59,
#  'crowdstrike': 59,
#  'bloomberg': 59,
#  'isupportpresidenttrump': 58,
#  'capitalofisrael': 58,
#  'nomuslimrefugeesinusa': 58,
#  'stabs': 58,
#  'freetommynow': 58,
#  'godblessisrael': 58,
#  'protectthewest': 58,
#  'giletsjaunes': 58,
#  'washingtonpost': 58,
#  'tlaib': 58,
#  'norge': 58,
#  'justintrudeau': 57,
#  'indonesia': 57,
#  'malaysia': 57,
#  'fvd': 57,
#  'hatecrimes': 57,
#  'israeli': 57,
#  'migrantcrisis': 57,
#  'removetlaib': 57,
#  'liarliarpantiesonfire': 57,
#  'destroyislam': 56,
#  'lockhimup': 56,
#  'dutch': 56,
#  'hezbollah': 56,
#  'patriot': 56,
#  'female': 56,
#  'prison': 56,
#  'killed': 56,
#  'cops': 56,
#  'respecttheflag': 56,
#  'proudamerican': 56,
#  'maga2020': 56,
#  'apostates': 56,
#  'nogozones': 55,
#  'slavery': 55,
#  'antisemitism': 55,
#  'judgejeanine': 55,
#  'punishment': 55,
#  'manchester': 55,
#  'raped': 55,
#  'parijs': 55,
#  'ramadan2018': 55,
#  'mn': 55,
#  'sendthemback': 54,
#  'hatespeech': 54,
#  'democratshateamerica': 54,
#  'turkish': 54,
#  'beheading': 54,
#  'girl': 54,
#  'iranian': 54,
#  'ied': 54,
#  'unitednations': 54,
#  'peeonkoran': 53,
#  'afghan': 53,
#  'waronchristians': 53,
#  'banradicalislam': 53,
#  'newmexico': 53,
#  'ellison': 53,
#  'skinned': 53,
#  'banislamregime': 53,
#  'stopteachinghateislam': 52,
#  'refugeeswelcome': 52,
#  'codeofvets': 52,
#  'christianity': 52,
#  'luton': 52,
#  'factsoverfeelings': 52,
#  'oklahoma': 52,
#  'islamnotcompatiblewithdemocracy': 51,
#  'defendeurope': 51,
#  'justleavingthishere': 51,
#  'blacklivesmatter': 51,
#  'convicted': 51,
#  'violence': 51,
#  'moslims': 51,
#  'nederland': 51,
#  'endhealthcarecartel': 51,
#  'yellowvests': 51,
#  'jihadistnotwelcome': 50,
#  'winning': 50,
#  'presidenttrump': 50,
#  'islamicterror': 50,
#  'moslem': 50,
#  'hitler': 50,
#  'woman': 50,
#  'womensmarch2018': 50,
#  'pope': 50,
#  'intelligence': 50,
#  'sennels': 50,
#  'headcoverings': 50,
#  'islambadforwomen': 49,
#  'stopimmigration': 49,
#  'muslimsupremist': 49,
#  'endvisalottery': 49,
#  'womensmarch': 49,
#  'tednugents': 49,
#  'stopthemadness': 49,
#  'islamicquotes': 49,
#  'ukip': 49,
#  'stopopressionofwomen': 49,
#  'whistleblower': 49,
#  'theislamicplan': 49,
#  'stoptheinvasion': 49,
#  'rally': 49,
#  'hypocrisy': 49,
#  'scotus': 49,
#  'animals': 49,
#  'vikings': 49,
#  'stopklimaathysterie': 49,
#  'kag2020landslide': 49,
#  'muslimracists': 48,
#  'muslimnazi': 48,
#  'muslimfacists': 48,
#  'muslimkiller': 48,
#  'nycterror': 48,
#  'oldmanstonezone': 48,
#  'montgomerycounty': 48,
#  'european': 48,
#  'readthedamnquran': 48,
#  'family': 48,
#  'muslimrapegangs': 48,
#  'islamnotwelcomehere': 48,
#  'islamicregimmustgo': 48,
#  'foxnewschannel': 48,
#  'blexit': 48,
#  'rugby': 48,
#  'endslavery': 48,
#  'saudisarabia': 48,
#  'smh': 47,
#  'closeallmosquesnow': 47,
#  'traitorobama': 47,
#  'antwerpen': 47,
#  'osterzgebirge': 47,
#  'theenemyelite': 47,
#  'patriotsunited': 47,
#  'ramadanbombathon': 47,
#  'murders': 47,
#  'strasbourg': 47,
#  'restart': 47,
#  'turquey': 47,
#  'godblessorban': 47,
#  'orbán': 47,
#  'deepstate': 46,
#  'radicalislam': 46,
#  'mbga': 46,
#  'dems': 46,
#  'greatbritain': 46,
#  'openyoureyes': 46,
#  'islamisnotareligionofpeace': 46,
#  'abuse': 46,
#  'church': 46,
#  'ps19': 46,
#  'knives': 46,
#  'bordercrisis': 46,
#  'silentnomore': 46,
#  'veteransday2017': 45,
#  'islamicregimemustgo': 45,
#  'huddersfield': 45,
#  'omar': 45,
#  '7goptraitors': 45,
#  'mechelen': 45,
#  'islamisadeathcult': 44,
#  'daesh': 44,
#  'religionofdeath': 44,
#  'islamisation': 44,
#  'conservative': 44,
#  'deportation': 44,
#  'virginia': 44,
#  'trudeaufortreason': 44,
#  'newyearseve': 44,
#  'maine': 44,
#  '2adefenders': 44,
#  'islamisslaveryforwomen': 44,
#  'qisreal': 44,
#  'saveeurpe': 44,
#  'illegalaliens': 44,
#  'stopchildmarriage': 44,
#  'voteredtosaveamerica': 44,
#  'vrijheid': 44,
#  'camp': 44,
#  'arab': 43,
#  'justice': 43,
#  'criminal': 43,
#  '911neverforget': 43,
#  'flight': 43,
#  'aq': 43,
#  'taqyyia': 43,
#  'democratsaredestroyingamerica': 43,
#  'islambadforgirls': 42,
#  'molonlabe': 42,
#  'banthekoran': 42,
#  'yazidi': 42,
#  'britainfirst': 42,
#  'melbourne': 42,
#  'proisrael': 42,
#  'merkelmussweg': 42,
#  'pregnant': 42,
#  '2ashallnotbeinfringed': 42,
#  'deplorable': 42,
#  'suicide': 42,
#  'savethechildren': 42,
#  'somalia': 42,
#  'religious': 42,
#  'kaga2020': 42,
#  'rapefugees': 41,
#  'banburka': 41,
#  'bansocialism': 41,
#  'deusvult': 41,
#  'islamishate': 41,
#  'stopislamicterror': 41,
#  'denmark': 41,
#  'bannationofislam': 41,
#  'progressive': 41,
#  'closeborders': 41,
#  'forbritain': 41,
#  'knowthetruthaboutislam': 41,
#  'sendthemallback': 41,
#  'lutf': 41,
#  'banworldhijabdaydays': 41,
#  'islamteachesus': 41,
#  'arrested': 41,
#  'muslimsdontassimilate': 41,
#  'roseanne': 41,
#  'protest': 41,
#  'conquest': 41,
#  'vermont': 41,
#  'elect': 41,
#  'mali': 41,
#  'protectlittlegirls': 40,
#  'tuesdaythoughts': 40,
#  'islamisierung': 40,
#  'religionofhate': 40,
#  'lgbtq': 40,
#  'newyorkcity': 40,
#  'refugeeban': 40,
#  'traitors': 40,
#  'gangrape': 40,
#  'democracy': 40,
#  'western': 40,
#  'sermon': 40,
#  'youtube': 40,
#  'fire': 40,
#  'islamophobiaisbs': 40,
#  'gangraped': 40,
#  'law': 40,
#  'ban_islam': 40,
#  'deportallmoslums': 40,
#  'lies': 40,
#  'loveitorgtfo': 40,
#  'jizyah': 40,
#  'sanbernardinojihadattack': 40,
#  'remember': 40,
#  'lockthemallup': 39,
#  'winstonchurchill': 39,
#  'oulu': 39,
#  'dontcairforomar': 39,
#  'banmuhammad': 39,
#  'islamisnotareligion': 38,
#  'childbrides': 38,
#  'banmosque': 38,
#  'mcga': 38,
#  'görlitz': 38,
#  'hindus': 38,
#  'protectwesternkids': 38,
#  'bomber': 38,
#  'girls': 38,
#  'marriage': 38,
#  'jail': 38,
#  'trudeauthemenace': 38,
#  'muslimah': 38,
#  'capitalpunishment': 38,
#  'deportomar': 38,
#  'smuggling': 38,
#  'choudary': 38,
#  'satansspawn': 37,
#  'christmasmarket': 37,
#  'jihadist': 37,
#  'yournext': 37,
#  'torture': 37,
#  'weapons': 37,
#  'mogadishu': 37,
#  'deaths': 37,
#  'rutte3wegermee': 37,
#  'backtheblue': 36,
#  'savethewest': 36,
#  'womensrights': 36,
#  'left': 36,
#  'iraq': 36,
#  'nosanctuarycities': 36,
#  'seehofer': 36,
#  'innenminister': 36,
#  'peaceful': 36,
#  'sjs': 36,
#  'cairo': 36,
#  'wheniwasamuslim': 36,
#  'rashidatlaibistheenemy': 36,
#  'mrgoodbarr': 36,
#  'garlandshooting': 35,
#  'radicalislamicterrorists': 35,
#  'soros': 35,
#  'pedophile': 35,
#  'brussels': 35,
#  'religionsbeliefs': 35,
#  'un': 35,
#  'banshiralaw': 35,
#  'nomuslimbanever': 35,
#  'subway': 35,
#  'spd': 35,
#  'yazidis': 35,
#  'orban': 35,
#  'virtuesignaling': 35,
#  'immigrant': 35,
#  'college': 35,
#  'iamtommy': 35,
#  'stopislamisation': 35,
#  'murderer': 35,
#  'standasone': 35,
#  'omarresign': 35,
#  'roma': 35,
#  'exmuslims': 34,
#  'pjnet': 34,
#  'fakefeminist': 34,
#  'pckills': 34,
#  'nypd': 34,
#  'sexoffender': 34,
#  'utrecht': 34,
#  'cleric': 34,
#  'faith': 34,
#  'downingstreet': 34,
#  'enemies': 34,
#  'humanrights': 34,
#  'magapatriot': 34,
#  'keithellison': 34,
#  'thesepeoplearesick': 34,
#  'cpac': 34,
#  'pedophilia': 33,
#  'muslimterrorism': 33,
#  'masa': 33,
#  'macron': 33,
#  'stopinvasione': 33,
#  'freeiran': 33,
#  'trafficking': 33,
#  'incompetent': 33,
#  'indoctrination': 33,
#  'barry': 33,
#  'beheads': 33,
#  'cop': 33,
#  'timetobancairnational': 33,
#  'whitehall': 33,
#  'penalty': 33,
#  'mulhouse': 33,
#  'citizen': 33,
#  'northdakota': 33,
#  'race': 33,
#  'satanists': 33,
#  'adultery': 33,
#  'andersoncooper': 33,
#  'quebec': 32,
#  'historymatters': 32,
#  'nomigrants': 32,
#  'kateslaw': 32,
#  'switzerland': 32,
#  'values': 32,
#  'czech': 32,
#  'pvvrotterdam': 32,
#  'regierung': 32,
#  'frankrijk': 32,
#  'shootings': 32,
#  'trudeaugroper': 32,
#  'party': 32,
#  'ngos': 32,
#  'isisbride': 32,
#  'february': 32,
#  'victimhood': 32,
#  'offense': 32,
#  'reinstatethemccarrenwalteract': 32,
#  'stoptheislamizationoftheworld': 31,
#  'truexit2019': 31,
#  'takeaknee': 31,
#  'nofgm': 31,
#  'deportillegalaliens': 31,
#  ...}

# %%
new_df = df.copy()
new_df['date'] = pd.to_datetime(new_df['created_at']).dt.date
new_df.index = new_df['date']
new_df = new_df[['entities']]
new_df.head()
# Out:
#                                                      entities
# date
# 2017-10-22  {"hashtags":[{"text":"BanIslam","indices":[93,...
# 2017-10-22  {"hashtags":[{"text":"muslim","indices":[16,23...
# 2017-10-22  {"hashtags":[{"text":"Raqqa","indices":[37,43]...
# 2017-10-22  {"hashtags":[],"symbols":[],"user_mentions":[{...
# 2017-10-22  {"hashtags":[{"text":"RT","indices":[51,54]},{...

# %%
datetime_dict = defaultdict(lambda: defaultdict(dict))

def get_counts(entity):
    table = defaultdict(int)
    test = json.loads(entity)
    for x in test['hashtags']:
        table[x['text'].lower()] += 1
    return table
    

for idx, row in tqdm(new_df.iterrows()):
    datetime_dict[idx] = dict(Counter(datetime_dict[idx]) + Counter(get_counts(row['entities'])))
# Out:
# 119019it [00:18, 6306.19it/s]

# %%
df_bar_chart_race = pd.DataFrame.from_dict(datetime_dict,orient='index').fillna(value=0).cumsum()
bcr.bar_chart_race(df = df_bar_chart_race.head(), 
                   n_bars=5, 
                   title = "Popular Hashtags (2017-2021)", 
                   period_length=250,
                   bar_kwargs={'alpha': .7},
                   bar_label_size=7)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 127 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 128 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 129 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 130 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 131 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 132 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 133 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 134 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 135 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 136 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 137 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 138 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 139 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 140 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 141 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 142 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 143 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 144 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 145 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 146 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 147 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 148 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 149 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 150 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 151 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 152 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 153 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 154 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 155 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 156 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 157 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 158 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 159 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 746 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 747 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 751 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 752 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 753 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 754 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 756 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 757 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 758 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 760 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 761 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 762 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 763 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 764 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 765 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 766 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 767 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 848 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 852 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 853 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 854 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 857 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 859 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 867 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 868 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 869 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 870 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 871 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 872 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 873 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 874 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 875 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 876 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 877 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 878 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 879 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 888 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 889 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 895 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 896 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 897 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 898 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 899 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 907 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 909 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 930 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1318 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1319 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1320 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1321 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1322 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1323 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1324 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1325 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1326 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1327 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1328 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1367 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1368 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1376 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1416 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1419 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1420 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1421 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1422 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1423 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1424 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1425 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1426 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1427 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1428 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1429 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1430 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1431 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1432 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1433 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1434 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1435 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1436 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1437 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1438 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1439 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1440 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1441 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1442 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1443 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1444 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1445 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1446 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1447 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1448 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1449 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1450 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1451 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1452 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1453 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1454 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1455 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1476 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1477 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1480 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1481 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1482 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1483 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1484 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1485 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1486 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1487 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1515 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1516 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1517 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1518 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1519 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1525 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1526 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1527 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1528 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1529 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1530 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1531 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1532 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1533 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1534 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1535 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1536 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1537 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1538 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1539 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1540 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1541 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1544 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1547 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1549 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1550 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1551 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1552 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1553 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1554 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1555 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1556 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1558 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1559 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1560 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1561 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1562 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1564 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1565 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1566 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1568 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1595 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1596 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1597 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1598 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1599 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1622 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1624 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1625 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1627 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1628 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1629 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1630 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1631 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1649 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1650 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1651 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1653 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1654 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1655 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1656 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1728 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1729 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1730 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1731 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1732 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1733 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1737 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1738 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1741 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1743 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1745 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1746 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1747 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1748 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1750 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1751 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1752 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1753 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1754 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1755 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1756 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1757 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1758 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1759 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1760 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1761 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1762 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 1763 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 26465 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 49352 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 47196 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 50868 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 48708 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 49345 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 51012 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 44592 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 45796 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 47140 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 48169 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 53444 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 49548 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 45380 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 45800 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 51068 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 51032 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 54868 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 50577 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 50672 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 12452 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 12473 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 12521 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 12512 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 25945 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 21205 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 29289 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 34384 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 24453 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 24859 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 35703 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 12486 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 12524 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 12499 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 12364 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 32118 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 23550 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 12395 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 22577 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 36947 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 12375 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 12394 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 12356 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 12491 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 12517 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 12540 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 31227 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 27665 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 21453 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 28040 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 12383 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 12425 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 22679 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 12360 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 12427 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 65305 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 26465 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 49352 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 47196 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 50868 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 48708 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 49345 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 51012 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 44592 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 45796 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 47140 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 48169 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 53444 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 49548 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 45380 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 45800 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 51068 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 51032 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 54868 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 50577 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 50672 missing from current font.
#   font.set_text(s, 0, flags=flags)
# <video width="1338" height="504" controls autoplay loop>
#   <source type="video/mp4" src="...
